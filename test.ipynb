# %%
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2], 'B':['a','b']})

# %%
row = pd.DataFrame({'A':[1], 'B':['b']})

# %%
row.isin(df.reset_index()).all(axis = None)
# Out:
# False

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#             current_time                                              title  \
# 0    2023-03-09 19:46:40  Paul Frankl Style Six Strand Pretzel Three Sea...
# 1    2023-03-09 19:46:36  Special ivory gold sofa loveseat set 🤩 no cred...
# 2    2023-03-09 19:46:32                                              Couch
# 3    2023-03-09 19:46:29                                           Sofa Set
# 4    2023-03-09 19:46:25  (NEW-OPEN BOX) Albany Park Kova Modular Cloud ...
# ..                   ...                                                ...
# 268  2023-03-09 18:00:08  Massage / Heating Brown Faux Leather Electric ...
# 269  2023-03-09 18:00:11  Malibu black sectional ÃÂÃÂÃÂÃÂ¢ÃÂÃÂ...
# 270  2023-03-09 18:00:15                3 Seater Couch - Galleria Furniture
# 271  2023-03-09 18:00:18           GLANDE HCXZ TWO TONE LIVING ROOM SET 3PC
# 272  2023-03-09 18:00:21                                Couch Set Reclining
#
#                                   time_location  \
# ...

# %%
columns = ['title', 'price']
row = pd.DataFrame({'title': ['Couch'], 'price': ['$400']})
row[columns].isin(df[columns].reset_index()).all(axis=None)
# Out:
# False

# %%
row[columns].isin(df[columns].reset_index())
# Out:
#    title  price
# 0  False  False

# %%
row[columns]
# Out:
#    title price
# 0  Couch  $400

# %%
# Out:
#            current_time  title                            time_location price  \
# 2   2023-03-09 19:46:32  Couch  Listed 51 minutes ago in Sugar Land, TX  $400
# 33  2023-03-09 19:32:11  Couch  Listed 36 minutes ago in Sugar Land, TX  $400
#
#                                    picture_links_list  \
# 2   ['https://scontent-dfw5-1.xx.fbcdn.net/v/t45.5...
# 33  ['https://scontent-dfw5-1.xx.fbcdn.net/v/t45.5...
#
#                                             item_link
# 2   https://www.facebook.com/marketplace/item/1427...
# 33  https://www.facebook.com/marketplace/item/1427...

# %%
df[columns]
# Out:
#                                                  title  \
# 0    Paul Frankl Style Six Strand Pretzel Three Sea...
# 1    Special ivory gold sofa loveseat set 🤩 no cred...
# 2                                                Couch
# 3                                             Sofa Set
# 4    (NEW-OPEN BOX) Albany Park Kova Modular Cloud ...
# ..                                                 ...
# 268  Massage / Heating Brown Faux Leather Electric ...
# 269  Malibu black sectional ÃÂÃÂÃÂÃÂ¢ÃÂÃÂ...
# 270                3 Seater Couch - Galleria Furniture
# 271           GLANDE HCXZ TWO TONE LIVING ROOM SET 3PC
# 272                                Couch Set Reclining
#
#                                                  price
# 0                                                 $695
# 1                                   $100\n  · In stock
# 2                                                 $400
# 3                                                 $400
# ...
